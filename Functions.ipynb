# %%
def calc_area( radius ):
  area=3.142*radius*radius
  print(area)
  return
calc_area(5)

def calc_area( radius ):
  area=3.142*radius*radius
  print(area)
calc_area(5)

def calc_area( radius ):
  area=3.142*radius*radius
  return area
calc_area(5)
# Out:
# 78.55
# 78.55
# 78.55

# %%
#call bby value
def calc_area( radius ):
 area=3.142*radius*radius
 print ("The area is " + str(area))
 radius*=2
 return
r=float(input("Enter the radius of a circle : "))
print (r)
calc_area (r)
print (r)
# Out:
# Enter the radius of a circle : 7
# 7.0
# The area is 153.958
# 7.0

# %%
#call by reference
def calc_volume( args):
 vol=3.142* args [0]* args [0]* args[1]
 print ("The volume is " + str(vol) + " cubed")
 args[0]*=2
 return
dimensions=[7,10]
print(dimensions) # before the function call
calc_volume (dimensions) # first call to the function
print(dimensions) # after the function call
# Out:
# [7, 10]
# The volume is 1539.58 cubed
# [14, 10]

# %%
#required arguements
#number of function call atrguements should match with function definition
def calc_volume(radius, height):
 vol=3.142* radius*radius *height
 print ("The volume is " + str(vol) + " cubed")
 return
calc_volume (7, 10) # function call using required arguments
# Out:
# The volume is 1539.58 cubed

# %%
#call by keyword arguements
calc_volume (height=10, radius=7) # function call using keyword arguments
# Out:
# The volume is 1539.58 cubed

# %%
#default arguements
def calc_volume(radius, height=10):
 vol=3.142* radius*radius *height
 print ("The volume is " + str(vol) + " cubed")
 return
calc_volume (7) # function call using default arguments
calc_volume (7,14) # function call without using default arguments
# Out:
# The volume is 1539.58 cubed
# The volume is 2155.412 cubed

# %%
#variable length arguements
def calc_volume(r, *varHeight):
  for height in varHeight:
    print ("The volume is " + str(3.142* r* r *height) + " cubed")
  return
calc_volume(7,10,20,30,40)
# Out:
# The volume is 1539.58 cubed
# The volume is 3079.16 cubed
# The volume is 4618.74 cubed
# The volume is 6158.32 cubed

# %%
#variable length arguements
def calc_volume(r, *varHeight):
 for height in varHeight:
  volume=3.142*r*r*height
  print ("The volume is " + str(volume) + " cubed")
 return
calc_volume(7,10,20,30,40)
# Out:
# The volume is 1539.58 cubed
# The volume is 3079.16 cubed
# The volume is 4618.74 cubed
# The volume is 6158.32 cubed

# %%
#anonymous functions
vol = lambda radius, height: 3.142*radius**2*height # Function definition in one line
print ("Volume is: ", vol (10, 2)) # a function call
# Out:
# Volume is:  628.4
